# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"C:\Users\user\OneDrive\demographics.csv")

# %%
data.head()
# Out:
#   location_key  population  population_male  population_female  \
# 0           AD     77265.0          58625.0            55581.0
# 1           AE   9890400.0        6836349.0          3054051.0
# 2           AF  38928341.0       19976265.0         18952076.0
# 3       AF_BAL   1509183.0              NaN                NaN
# 4       AF_BAM    495557.0              NaN                NaN
#
#    population_rural  population_urban  population_largest_city  \
# 0            9269.0           67873.0                      NaN
# 1         1290785.0         8479744.0                2833079.0
# 2        28244481.0         9797273.0                4114030.0
# 3               NaN               NaN                      NaN
# 4               NaN               NaN                      NaN
#
#    population_clustered  population_density  human_development_index  \
# 0                   NaN             164.394                    0.858
# ...

# %%
data.columns
# Out:
# Index(['location_key', 'population', 'population_male', 'population_female',
#        'population_rural', 'population_urban', 'population_largest_city',
#        'population_clustered', 'population_density', 'human_development_index',
#        'population_age_00_09', 'population_age_10_19', 'population_age_20_29',
#        'population_age_30_39', 'population_age_40_49', 'population_age_50_59',
#        'population_age_60_69', 'population_age_70_79',
#        'population_age_80_and_older'],
#       dtype='object')

# %%
data.tail()
# Out:
#       location_key  population  population_male  population_female  \
# 21684    ZA_WC_DC3    286786.0              NaN                NaN
# 21685    ZA_WC_DC4    611278.0              NaN                NaN
# 21686    ZA_WC_DC5     74247.0              NaN                NaN
# 21687           ZM  18383956.0        9103006.0          9280950.0
# 21688           ZW  14862927.0        7092010.0          7770917.0
#
#        population_rural  population_urban  population_largest_city  \
# 21684               NaN               NaN                      NaN
# 21685               NaN               NaN                      NaN
# 21686               NaN               NaN                      NaN
# 21687         9989317.0         7871713.0                2646619.0
# 21688         9928163.0         4717305.0                1521311.0
#
#        population_clustered  population_density  human_development_index  \
# 21684                   NaN                 NaN                      NaN
# ...

# %%
data.describe()
# Out:
#          population  population_male  population_female  population_rural  \
# count  2.165900e+04     1.760700e+04       1.760700e+04      2.130000e+02
# mean   7.464804e+05     4.140895e+05       4.086139e+05      1.591651e+07
# std    1.482830e+07     8.501449e+06       8.037004e+06      7.372102e+07
# min    0.000000e+00     8.000000e+00       1.700000e+01      0.000000e+00
# 25%    4.754000e+03     2.413500e+03       2.363500e+03      2.051630e+05
# 50%    1.717300e+04     7.460000e+03       7.403000e+03      1.758851e+06
# 75%    7.963800e+04     2.766600e+04       2.820550e+04      9.989317e+06
# max    1.439324e+09     7.382473e+08       7.010764e+08      8.953862e+08
#
#        population_urban  population_largest_city  population_clustered  \
# count      2.130000e+02             1.520000e+02          1.210000e+02
# mean       1.997289e+07             4.484559e+06          1.489624e+07
# std        7.153961e+07             6.015669e+06          4.408693e+07
# ...

# %%
data.isnull().sum()
# Out:
# location_key                       1
# population                        30
# population_male                 4082
# population_female               4082
# population_rural               21476
# population_urban               21476
# population_largest_city        21537
# population_clustered           21568
# population_density             20497
# human_development_index        15951
# population_age_00_09            4440
# population_age_10_19            4441
# population_age_20_29            4441
# population_age_30_39            4433
# population_age_40_49            4439
# population_age_50_59            4457
# population_age_60_69            4475
# population_age_70_79            4562
# population_age_80_and_older     4729
# dtype: int64

# %%
sns.relplot(x="population_female",y="population_male",hue="population_rural",data=data)

# %%
data.columns
# Out:
# Index(['location_key', 'population', 'population_male', 'population_female',
#        'population_rural', 'population_urban', 'population_largest_city',
#        'population_clustered', 'population_density', 'human_development_index',
#        'population_age_00_09', 'population_age_10_19', 'population_age_20_29',
#        'population_age_30_39', 'population_age_40_49', 'population_age_50_59',
#        'population_age_60_69', 'population_age_70_79',
#        'population_age_80_and_older'],
#       dtype='object')

# %%
sns.relplot(x="population_female",y="population_male",kind="line",data=data)

# %%
sns.catplot(x="population_female",y="population_male",data=data)
